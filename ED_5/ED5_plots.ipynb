# %% [markdown]
# # import

# %% [markdown]
# # figure A

# %% [markdown]
# # figure B

# %% [markdown]
# # figure C

# %% [markdown]
# # figure D

# %% [markdown]
# # figure E

# %% [markdown]
# # figure F

# %% [markdown]
# # figure G

# %% [markdown]
# # figure H

# %% [markdown]
# # figure I

# %% [markdown]
# # figure J
