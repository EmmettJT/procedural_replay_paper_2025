# %% [markdown]
# # import

# %% [markdown]
# # figure C

# %% [markdown]
# # figure D

# %% [markdown]
# # figure E

# %% [markdown]
# # figure G

# %% [markdown]
# # figure I

# %% [markdown]
# # figure K

# %% [markdown]
# # figure M
