# %% [markdown]
# # import

# %% [markdown]
# # figure C

# %% [markdown]
# # figure D

# %% [markdown]
# # figure E

# %% [markdown]
# # figure F

# %% [markdown]
# # figure H

# %% [markdown]
# # figure K

# %% [markdown]
# # figure L

# %% [markdown]
# # figure M

# %%
# from new analysis

# %% [markdown]
# # figure N

# %% [markdown]
# # figure O

# %% [markdown]
# # figure P
