# %% [markdown]
# # import

# %% [markdown]
# # figure C

# %% [markdown]
# # figure D

# %% [markdown]
# # figure E

# %% [markdown]
# # figure F

# %% [markdown]
# # figure G

# %% [markdown]
# # figure H

# %% [markdown]
# # figure I

# %% [markdown]
# # figure J

# %% [markdown]
# # figure K

# %% [markdown]
# # figure L

# %% [markdown]
# # figure M

# %% [markdown]
# # figure N

# %% [markdown]
# # figure O

# %% [markdown]
# # figure P

# %% [markdown]
# # figure Q

# %% [markdown]
# # figure R
